# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
url = ("https://en.wikipedia.org/wiki/Pontiac_Firebird")

# %%
response = requests.get(url)

# %%
response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.content, "html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Pontiac Firebird - Wikipedia</title>
# ...

# %%
soup.select("p")[0].get_text()
# Out:
# "The Pontiac Firebird is an American automobile that was built and produced by Pontiac from the 1967 to 2002 model years.[1] Designed as a pony car to compete with the Ford Mustang, it was introduced on February 23, 1967, five months after GM's Chevrolet division's platform-sharing Camaro.[2] This also coincided with the release of the 1967 Mercury Cougar, Ford's upscale, platform-sharing version of the Mustang.[3][4]\n"

# %%
soup.select("#mw-content-text > div.mw-parser-output > table:nth-child(116) > tbody > tr:nth-child(1) > th:nth-child(1)")
# Out:
# [<th>Model year</th>]

# %%
soup.select("span#Models.mw-headline")
# Out:
# [<span class="mw-headline" id="Models">Models</span>]

# %%
soup.select("#mw-content-text > div.mw-parser-output > ul:nth-child(129) > li:nth-child(1)")
# Out:
# [<li>Firebird base</li>]

# %%
soup.select("#mw-content-text > div.mw-parser-output > ul:nth-child(129) > li:nth-child(2)")
# Out:
# [<li>Firebird S/E (1982–1987)</li>]

# %%
soup.select("#mw-content-text > div.mw-parser-output > ul:nth-child(129) > li:nth-child(3)")
# Out:
# [<li>Firebird Formula (1987–1992)</li>]

# %%
soup.select("#mw-content-text > div.mw-parser-output > ul:nth-child(129) > li:nth-child(4)")
# Out:
# [<li>Firebird Trans Am</li>]
